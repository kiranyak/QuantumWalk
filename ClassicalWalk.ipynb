# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# defining function of 1-D Random Walk
def Randomwalk1D(n):
    x = 0
    y = 0
    xposition = [0]
    yposition = [0]
    for i in range (1,n+1):
        step = np.random.uniform(0,1)
        if step < 0.5:
            x += 1
            y +=1
        else:
            x +=1
            y += -1
        xposition.append(x)
        yposition.append(y)
    return [xposition, yposition]

# %%
Randwalk1 = Randomwalk1D(1000)
Randwalk2 = Randomwalk1D(1000)
Randwalk3 = Randomwalk1D(1000)
plt.plot(Randwalk1[0],Randwalk1[1],'g-', label = "Randwalk1D")
plt.plot(Randwalk2[0],Randwalk2[1],'r-', label = "Randwalk1D")
plt.plot(Randwalk3[0],Randwalk3[1],'y-', label = "Randwalk1D")
plt.title("1-D Random Walks")
plt.show()

# %%
import random
import pylab
n = 5000 #n is the number of steps(increase in the value of n increses the compelxity of graph) 
x = np.zeros(n) # x and y are arrays which store the coordinates of the position 
y = np.zeros(n) 
direction=["NORTH","SOUTH","EAST","WEST"] # Assuming the four directions of movement.
for i in range(1, n): 
    step = random.choice(direction) #Randomly choosing the direction of movement. 
    if step == "EAST": #updating the direction with respect to the direction of motion choosen.
        x[i] = x[i - 1] + 1
        y[i] = y[i - 1] 
    elif step == "WEST": 
        x[i] = x[i - 1] - 1
        y[i] = y[i - 1] 
    elif step == "NORTH": 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] + 1
    else: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] - 1
pylab.title("Random Walk 2-D")
pylab.plot(x, y) #plotting the walk.
pylab.show()

# %%
from operator import mul    # or mul=lambda x,y:x*y
from fractions import Fraction



#  number of steps = 100 and p = 1/2 

def nCk(n,k):    
      return int(functools.reduce(mul, (Fraction(n-i, i+1) for i in range(k)), 1) )
p = []
for i in range(-50,50):
    p.append(i)
position = np.array(p)
probabilityAtPosition = []
for i in p:
    if (i%2 == 0):
        p = (i+100)//2
        q = nCk(100,p)
        r = 2**100
        z = q/r
        #print(z)
        probabilityAtPosition.append(z)
    else:
        probabilityAtPosition.append(0)
plt.plot(position,probabilityAtPosition)
plt.title("Probability Distribution of Random Walk")
plt.show()
